# %%
import requests

from bs4 import BeautifulSoup

def data_fetcher(url):
    dummy="https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt"
    r = requests.get(url)


    soup = BeautifulSoup(r.text)
    credit_default_tag=list()

    for tag in soup.find_all('tr'):
        for child in tag.childGenerator():
            try:
                list1=child.find_all('font')
                for i in list1 :
                    if (str(i.text) == "Credit Default Swap"):
                        credit_default_tag.append(i)
            except Exception as e:
                pass


    credit_default_final_tags=list()

    for k in credit_default_tag:
        try:
            if(len(k.text)>3):
                credit_default_final_tags.append(k)    

        except Exception as e:
            print e


    parent_tags=list()
    fields=list()

    for i in credit_default_final_tags:
        parent_tags.append(i.parent.parent.parent.parent)

    for each_tag in parent_tags:
        fields.append(each_tag.next_sibling.next_sibling)

    final_list =list()
    for j in fields:
        temp_list=list()
        for i in j.children :
            try:
                print i.p.font.get_text()
                temp_list.append(unicode(i.p.font.get_text()))

            except Exception as e:
                pass
        final_list.append(tuple(temp_list))

    return final_list

# %%
import pandas as pd
import numpy as np

# %%
inputfile = pd.read_excel("Input.xlsx")

# %%
inputfile
# Out:
#          CIK                                       Company Name Date Filed  \
# 0      35315                        FIDELITY FIXED INCOME TRUST 2003-06-27
# 1    1011378                  UNIVERSAL INSTITUTIONAL FUNDS INC 2003-08-28
# 2    1056707                      DREYFUS INVESTMENT PORTFOLIOS 2003-09-04
# 3    1056707                      DREYFUS INVESTMENT PORTFOLIOS 2003-08-26
# 4    1131013                                  AB FUNDS TRUST/DE 2003-08-26
# 5    1160990                        PIMCO CORPORATE INCOME FUND 2003-07-02
# 6      19469                                PHOENIX SERIES FUND 2003-07-03
# 7     356494                   VARIABLE INSURANCE PRODUCTS FUND 2003-08-29
# 8      53808                         DREYFUS LAUREL FUNDS TRUST 2003-09-03
# 9     751199                          FIDELITY INCOME FUND /MA/ 2003-09-26
# 10    795422                         FIDELITY ADVISOR SERIES II 2003-07-03
# 11    797073                 DREYFUS PREMIER FIXED INCOME FUNDS 2003-07-02
# 12    813383                   DREYFUS VARIABLE INVESTMENT FUND 2003-09-04
# 13    813383                   DREYFUS VARIABLE INVESTMENT FUND 2003-08-19
# 14    814679                             AMERICAN SKANDIA TRUST 2003-09-05
# 15    816754                               ACM  INCOME FUND INC 2003-09-09
# 16    825316  ALLIANCEBERNSTEIN VARIABLE PRODUCTS SERIES FUN... 2003-08-29
# 17    826737                       PHOENIX MULTI PORTFOLIO FUND 2003-08-07
# 18    831016                VARIABLE INSURANCE PRODUCTS FUND II 2003-08-29
# 19    884122                         PHOENIX MULTI SERIES TRUST 2003-07-03
# 20    890881          ALLIANCE WORLD DOLLAR GOVERNMENT FUND INC 2003-07-07
# 21    927384                    VARIABLE INSURANCE PRODUCTS III 2003-08-29
# 22    944684                             UBS RELATIONSHIP FUNDS 2003-09-05
# 23   1219360                             PIMCO HIGH INCOME FUND 2003-12-03
# 24    205323                        FIDELITY COMMONWEALTH TRUST 2003-12-23
# 25     30151                           DREYFUS A BONDS PLUS INC 2003-11-24
# 26     35315                        FIDELITY FIXED INCOME TRUST 2003-12-24
# 27    354046                      FIDELITY CHARLES STREET TRUST 2003-11-26
# 28    741375            MORGAN STANLEY INSTITUTIONAL FUND TRUST 2003-11-28
# 29    795422                         FIDELITY ADVISOR SERIES II 2003-12-29
# ..       ...                                                ...        ...
# 77   1002718  ALLIANCEBERNSTEIN GLOBAL STRATEGIC INCOME TRUS... 2004-07-09
# 78   1014913                                FRONTEGRA FUNDS INC 2004-09-08
# 79   1035018                    STRATEGIC PARTNERS MUTUAL FUNDS 2004-07-08
# 80   1035018                    STRATEGIC PARTNERS MUTUAL FUNDS 2004-09-29
# 81   1046232                EVERGREEN SELECT FIXED INCOME TRUST 2004-07-08
# 82   1056707                      DREYFUS INVESTMENT PORTFOLIOS 2004-08-31
# 83   1119720                       STATE FARM MUTUAL FUND TRUST 2004-09-08
# 84   1131013                                  AB FUNDS TRUST/DE 2004-08-26
# 85   1160990                        PIMCO CORPORATE INCOME FUND 2004-07-09
# 86   1168575                    DREYFUS FIXED INCOME SECURITIES 2004-07-01
# 87   1190935                   PIMCO CORPORATE OPPORTUNITY FUND 2004-08-05
# 88     19469                                PHOENIX SERIES FUND 2004-07-07
# 89    356494                   VARIABLE INSURANCE PRODUCTS FUND 2004-09-01
# 90     53808                         DREYFUS LAUREL FUNDS TRUST 2004-08-26
# 91    722574                          FIDELITY ADVISOR SERIES I 2004-08-03
# 92    751199                          FIDELITY INCOME FUND /MA/ 2004-09-28
# 93    792359                           PHOENIX EDGE SERIES FUND 2004-09-07
# 94    810868                        LEGG MASON INCOME TRUST INC 2004-09-03
# 95     81205                             FIDELITY PURITAN TRUST 2004-09-28
# 96    813383                   DREYFUS VARIABLE INVESTMENT FUND 2004-08-17
# 97    814679                             AMERICAN SKANDIA TRUST 2004-09-07
# 98    816754                               ACM  INCOME FUND INC 2004-09-09
# 99    825316  ALLIANCEBERNSTEIN VARIABLE PRODUCTS SERIES FUN... 2004-09-15
# 100   826737                       PHOENIX MULTI PORTFOLIO FUND 2004-08-05
# 101   831016                VARIABLE INSURANCE PRODUCTS FUND II 2004-08-23
# 102   831016                VARIABLE INSURANCE PRODUCTS FUND II 2004-09-01
# 103   831016                VARIABLE INSURANCE PRODUCTS FUND II 2004-09-01
# 104   837274  FRANKLIN TEMPLETON VARIABLE INSURANCE PRODUCTS... 2004-08-25
# 105   884122                         PHOENIX MULTI SERIES TRUST 2004-07-07
# 106   889169                 DREYFUS INVESTMENT GRADE FUNDS INC 2004-09-29
#
#                                         Filename Form Type  \
# 0      edgar/data/35315/0000035315-03-000001.txt     N-CSR
# 1    edgar/data/1011378/0001047469-03-029173.txt    N-CSRS
# 2    edgar/data/1056707/0001056707-03-000013.txt   N-CSR/A
# 3    edgar/data/1056707/0001056707-03-000011.txt     N-CSR
# 4    edgar/data/1131013/0000893220-03-001501.txt    N-CSRS
# 5    edgar/data/1160990/0001047469-03-023293.txt     N-CSR
# 6      edgar/data/19469/0000935069-03-000889.txt     N-CSR
# 7     edgar/data/356494/0000356494-03-000033.txt    N-CSRS
# 8      edgar/data/53808/0000717341-03-000004.txt     N-CSR
# 9     edgar/data/751199/0000751199-03-000007.txt     N-CSR
# 10    edgar/data/795422/0000795422-03-000025.txt     N-CSR
# 11    edgar/data/797073/0000797073-03-000011.txt     N-CSR
# 12    edgar/data/813383/0000813383-03-000016.txt   N-CSR/A
# 13    edgar/data/813383/0000813383-03-000014.txt     N-CSR
# 14    edgar/data/814679/0000893220-03-001540.txt    N-CSRS
# 15    edgar/data/816754/0000936772-03-000365.txt    N-CSRS
# 16    edgar/data/825316/0000936772-03-000324.txt     N-CSR
# 17    edgar/data/826737/0000935069-03-001044.txt     N-CSR
# 18    edgar/data/831016/0000831016-03-000009.txt    N-CSRS
# 19    edgar/data/884122/0000935069-03-000884.txt     N-CSR
# 20    edgar/data/890881/0000936772-03-000293.txt     N-CSR
# 21    edgar/data/927384/0000927384-03-000012.txt    N-CSRS
# 22    edgar/data/944684/0001047469-03-029981.txt    N-CSRS
# 23   edgar/data/1219360/0001047469-03-039077.txt    N-CSRS
# 24    edgar/data/205323/0000205323-03-000029.txt    N-CSRS
# 25     edgar/data/30151/0000030151-03-000011.txt     N-CSR
# 26     edgar/data/35315/0000035315-03-000015.txt    N-CSRS
# 27    edgar/data/354046/0000354046-03-000003.txt     N-CSR
# 28    edgar/data/741375/0001047469-03-038751.txt     N-CSR
# 29    edgar/data/795422/0000795422-03-000041.txt     N-CSR
# ..                                           ...       ...
# 77   edgar/data/1002718/0000936772-04-000141.txt     N-CSR
# 78   edgar/data/1014913/0000898531-04-000283.txt     N-CSR
# 79   edgar/data/1035018/0001193125-04-115585.txt    N-CSRS
# 80   edgar/data/1035018/0001193125-04-163833.txt       N-Q
# 81   edgar/data/1046232/0000936772-04-000130.txt     N-CSR
# 82   edgar/data/1056707/0001056707-04-000028.txt     N-CSR
# 83   edgar/data/1119720/0001193125-04-153300.txt    N-CSRS
# 84   edgar/data/1131013/0000893220-04-001815.txt    N-CSRS
# 85   edgar/data/1160990/0001047469-04-022855.txt    N-CSRS
# 86   edgar/data/1168575/0001168575-04-000006.txt     N-CSR
# 87   edgar/data/1190935/0001047469-04-025424.txt    N-CSRS
# 88     edgar/data/19469/0000935069-04-000972.txt    N-CSRS
# 89    edgar/data/356494/0000927384-04-000026.txt    N-CSRS
# 90     edgar/data/53808/0000053808-04-000020.txt     N-CSR
# 91    edgar/data/722574/0000880709-04-000032.txt    N-CSRS
# 92    edgar/data/751199/0000751199-04-000012.txt     N-CSR
# 93    edgar/data/792359/0000935069-04-001411.txt    N-CSRS
# 94    edgar/data/810868/0000950133-04-003417.txt    N-CSRS
# 95     edgar/data/81205/0000081205-04-000022.txt     N-CSR
# 96    edgar/data/813383/0000813383-04-000015.txt     N-CSR
# 97    edgar/data/814679/0001193125-04-152315.txt    N-CSRS
# 98    edgar/data/816754/0000936772-04-000196.txt    N-CSRS
# 99    edgar/data/825316/0000936772-04-000204.txt    N-CSRS
# 100   edgar/data/826737/0000935069-04-001021.txt    N-CSRS
# 101   edgar/data/831016/0000356494-04-000040.txt    N-CSRS
# 102   edgar/data/831016/0000831016-04-000013.txt    N-CSRS
# 103   edgar/data/831016/0000927384-04-000027.txt    N-CSRS
# 104   edgar/data/837274/0001193125-04-146462.txt    N-CSRS
# 105   edgar/data/884122/0000935069-04-000970.txt    N-CSRS
# 106   edgar/data/889169/0000889169-04-000009.txt     N-CSR
#
#                                                    URL
# 0    https://www.sec.gov/Archives/edgar/data/35315/...
# 1    https://www.sec.gov/Archives/edgar/data/101137...
# 2    https://www.sec.gov/Archives/edgar/data/105670...
# 3    https://www.sec.gov/Archives/edgar/data/105670...
# 4    https://www.sec.gov/Archives/edgar/data/113101...
# 5    https://www.sec.gov/Archives/edgar/data/116099...
# 6    https://www.sec.gov/Archives/edgar/data/19469/...
# 7    https://www.sec.gov/Archives/edgar/data/356494...
# 8    https://www.sec.gov/Archives/edgar/data/53808/...
# 9    https://www.sec.gov/Archives/edgar/data/751199...
# 10   https://www.sec.gov/Archives/edgar/data/795422...
# 11   https://www.sec.gov/Archives/edgar/data/797073...
# 12   https://www.sec.gov/Archives/edgar/data/813383...
# 13   https://www.sec.gov/Archives/edgar/data/813383...
# 14   https://www.sec.gov/Archives/edgar/data/814679...
# 15   https://www.sec.gov/Archives/edgar/data/816754...
# 16   https://www.sec.gov/Archives/edgar/data/825316...
# 17   https://www.sec.gov/Archives/edgar/data/826737...
# 18   https://www.sec.gov/Archives/edgar/data/831016...
# 19   https://www.sec.gov/Archives/edgar/data/884122...
# 20   https://www.sec.gov/Archives/edgar/data/890881...
# 21   https://www.sec.gov/Archives/edgar/data/927384...
# 22   https://www.sec.gov/Archives/edgar/data/944684...
# 23   https://www.sec.gov/Archives/edgar/data/121936...
# 24   https://www.sec.gov/Archives/edgar/data/205323...
# 25   https://www.sec.gov/Archives/edgar/data/30151/...
# 26   https://www.sec.gov/Archives/edgar/data/35315/...
# 27   https://www.sec.gov/Archives/edgar/data/354046...
# 28   https://www.sec.gov/Archives/edgar/data/741375...
# 29   https://www.sec.gov/Archives/edgar/data/795422...
# ..                                                 ...
# 77   https://www.sec.gov/Archives/edgar/data/100271...
# 78   https://www.sec.gov/Archives/edgar/data/101491...
# 79   https://www.sec.gov/Archives/edgar/data/103501...
# 80   https://www.sec.gov/Archives/edgar/data/103501...
# 81   https://www.sec.gov/Archives/edgar/data/104623...
# 82   https://www.sec.gov/Archives/edgar/data/105670...
# 83   https://www.sec.gov/Archives/edgar/data/111972...
# 84   https://www.sec.gov/Archives/edgar/data/113101...
# 85   https://www.sec.gov/Archives/edgar/data/116099...
# 86   https://www.sec.gov/Archives/edgar/data/116857...
# 87   https://www.sec.gov/Archives/edgar/data/119093...
# 88   https://www.sec.gov/Archives/edgar/data/19469/...
# 89   https://www.sec.gov/Archives/edgar/data/356494...
# 90   https://www.sec.gov/Archives/edgar/data/53808/...
# 91   https://www.sec.gov/Archives/edgar/data/722574...
# 92   https://www.sec.gov/Archives/edgar/data/751199...
# 93   https://www.sec.gov/Archives/edgar/data/792359...
# 94   https://www.sec.gov/Archives/edgar/data/810868...
# 95   https://www.sec.gov/Archives/edgar/data/81205/...
# 96   https://www.sec.gov/Archives/edgar/data/813383...
# 97   https://www.sec.gov/Archives/edgar/data/814679...
# 98   https://www.sec.gov/Archives/edgar/data/816754...
# 99   https://www.sec.gov/Archives/edgar/data/825316...
# 100  https://www.sec.gov/Archives/edgar/data/826737...
# 101  https://www.sec.gov/Archives/edgar/data/831016...
# 102  https://www.sec.gov/Archives/edgar/data/831016...
# 103  https://www.sec.gov/Archives/edgar/data/831016...
# 104  https://www.sec.gov/Archives/edgar/data/837274...
# 105  https://www.sec.gov/Archives/edgar/data/884122...
# 106  https://www.sec.gov/Archives/edgar/data/889169...
#
# [107 rows x 6 columns]

# %%
inputfile['Date Filed']=inputfile['Date Filed'].iloc[0].strftime('%m/%d/%Y')

# %%
def tupleparser(tup,k):
    
    "(u'Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the\nnotional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional\nmultiplied by 1.37%', u'June 2007', u'$\t4,475', u'$\t15')"
    if(len(tup)==0):
        string = str(k+1)+"^"+str(inputfile['CIK'].iloc[k])\
            +"^"+str(inputfile['Company Name'].iloc[k])\
            +"^"+str(inputfile['Date Filed'].iloc[k])\
            +"^"+str(inputfile['Form Type'].iloc[k])\
            +"^"+str(inputfile['URL'].iloc[k])\
            +"^"+"NA"\
            +"^"+"NA"
        return_list=list()
        return_list.append(string)
        
        return return_list
    
    return_list=list()
   
    
    for count,j in enumerate(tup):
        string=str(k+1)+"^"+str(inputfile['CIK'].iloc[k])\
        +"^"+str(inputfile['Company Name'].iloc[k])\
        +"^"+str(inputfile['Date Filed'].iloc[k])\
        +"^"+str(inputfile['Form Type'].iloc[k])\
        +"^"+str(inputfile['URL'].iloc[k])+"^"
        
    
        if(count==0):
            val= str(j).replace('\n', ' ').replace('\r', '')
            string+="CDS Text"+"^"+val
           
            return_list.append(string)
            
        elif(count==1):
            
            string+="Expiration Date"+"^"+j;
            
            return_list.append(string)
        
        elif(count==2):
        
            string+="Notional Amount (000s)"+"^"+j
            
            return_list.append(string)
        
        elif(count==3):
            string+="Unrealized Appreciation/ (Depreciation) (000s)"+"^"+j
         
            return_list.append(string)
            
    return return_list

# %%
with open('third.txt','w')as f:
    for i in range(10):
        fetched_data=data_fetcher(inputfile['URL'].iloc[i])
        if(len(fetched_data)==0):
            dumtup=tuple()
            for k in tupleparser(dumtup,i):
                print k
                f.write(k+"\n")
        else:
            for m in fetched_data:
                for k in tupleparser(m,i):
                    print k
                    f.write(k+"\n")
# Out:
# Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the
# notional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional
# multiplied by 1.37%
# June 2007
# $	4,475
# $	15
# Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the
# notional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional
# multiplied by 1.37%
# June 2007
# $	4,475
# $	15
# Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the
# notional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional
# multiplied by 1.37%
# June 2007
# $	4,475
# $	15
# Receive from Morgan Stanley, Inc., upon default event of Vornado Realty Trust, par
# value of the notional amount of Vornado Realty Trust 5.625% 6/15/07 and pay
# quarterly notional multiplied by 1.37%
# June 2007
# $	5,575
# $	19
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^CDS Text^Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the notional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional multiplied by 1.37%
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Expiration Date^June 2007
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Notional Amount (000s)^$	4,475
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Unrealized Appreciation/ (Depreciation) (000s)^$	15
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^CDS Text^Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the notional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional multiplied by 1.37%
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Expiration Date^June 2007
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Notional Amount (000s)^$	4,475
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Unrealized Appreciation/ (Depreciation) (000s)^$	15
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^CDS Text^Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the notional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional multiplied by 1.37%
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Expiration Date^June 2007
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Notional Amount (000s)^$	4,475
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Unrealized Appreciation/ (Depreciation) (000s)^$	15
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^CDS Text^Receive from Morgan Stanley, Inc., upon default event of Vornado Realty Trust, par value of the notional amount of Vornado Realty Trust 5.625% 6/15/07 and pay quarterly notional multiplied by 1.37%
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Expiration Date^June 2007
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Notional Amount (000s)^$	5,575
# 1^35315^FIDELITY FIXED INCOME TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/35315/0000035315-03-000001.txt^Unrealized Appreciation/ (Depreciation) (000s)^$	19
# 2^1011378^UNIVERSAL INSTITUTIONAL FUNDS INC^06/27/2003^N-CSRS^https://www.sec.gov/Archives/edgar/data/1011378/0001047469-03-029173.txt^NA^NA
# 3^1056707^DREYFUS INVESTMENT PORTFOLIOS^06/27/2003^N-CSR/A^https://www.sec.gov/Archives/edgar/data/1056707/0001056707-03-000013.txt^NA^NA
# 4^1056707^DREYFUS INVESTMENT PORTFOLIOS^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/1056707/0001056707-03-000011.txt^NA^NA
# 5^1131013^AB FUNDS TRUST/DE^06/27/2003^N-CSRS^https://www.sec.gov/Archives/edgar/data/1131013/0000893220-03-001501.txt^NA^NA
# 6^1160990^PIMCO CORPORATE INCOME FUND^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/1160990/0001047469-03-023293.txt^NA^NA
# 7^19469^PHOENIX SERIES FUND^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/19469/0000935069-03-000889.txt^NA^NA
# Receive quarterly notional amount multiplied by .87% and pay Merrill Lynch, Inc. upon default of Raytheon Co., par
# value of the notional amount of Raytheon Co. 5.375% 4/1/13
# June 2008
# $	5,000,000
# $	16,161
# 8^356494^VARIABLE INSURANCE PRODUCTS FUND^06/27/2003^N-CSRS^https://www.sec.gov/Archives/edgar/data/356494/0000356494-03-000033.txt^CDS Text^Receive quarterly notional amount multiplied by .87% and pay Merrill Lynch, Inc. upon default of Raytheon Co., par value of the notional amount of Raytheon Co. 5.375% 4/1/13
# 8^356494^VARIABLE INSURANCE PRODUCTS FUND^06/27/2003^N-CSRS^https://www.sec.gov/Archives/edgar/data/356494/0000356494-03-000033.txt^Expiration Date^June 2008
# 8^356494^VARIABLE INSURANCE PRODUCTS FUND^06/27/2003^N-CSRS^https://www.sec.gov/Archives/edgar/data/356494/0000356494-03-000033.txt^Notional Amount (000s)^$	5,000,000
# 8^356494^VARIABLE INSURANCE PRODUCTS FUND^06/27/2003^N-CSRS^https://www.sec.gov/Archives/edgar/data/356494/0000356494-03-000033.txt^Unrealized Appreciation/ (Depreciation) (000s)^$	16,161
# 9^53808^DREYFUS LAUREL FUNDS TRUST^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/53808/0000717341-03-000004.txt^NA^NA
# Receive from Morgan Stanley, Inc., upon default of Vornado
# Realty Trust, par value of the notional amount of Vornado
# Realty Trust 5.625% 6/15/07, and pay quarterly notional
# amount multiplied by 1.37%
# June 2007
# $	200,000
# $	(1,261)
# Receive quarterly notional amount multiplied by 1.12%
# and pay Morgan Stanley, Inc. upon default of Comcast
# Cable Communications, Inc., par value of the notional
# amount of Comcast Cable Communications, Inc. 6.75%
# 1/30/11
# June 2006
# $	400,000
# $	3,195
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^CDS Text^Receive from Morgan Stanley, Inc., upon default of Vornado Realty Trust, par value of the notional amount of Vornado Realty Trust 5.625% 6/15/07, and pay quarterly notional amount multiplied by 1.37%
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^Expiration Date^June 2007
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^Notional Amount (000s)^$	200,000
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^Unrealized Appreciation/ (Depreciation) (000s)^$	(1,261)
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^CDS Text^Receive quarterly notional amount multiplied by 1.12% and pay Morgan Stanley, Inc. upon default of Comcast Cable Communications, Inc., par value of the notional amount of Comcast Cable Communications, Inc. 6.75% 1/30/11
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^Expiration Date^June 2006
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^Notional Amount (000s)^$	400,000
# 10^751199^FIDELITY INCOME FUND /MA/^06/27/2003^N-CSR^https://www.sec.gov/Archives/edgar/data/751199/0000751199-03-000007.txt^Unrealized Appreciation/ (Depreciation) (000s)^$	3,195
